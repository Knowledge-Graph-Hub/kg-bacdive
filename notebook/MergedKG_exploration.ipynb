# %%
# %reset -f

# %%
from pathlib import Path
import tarfile
import pandas as pd

# %%
MERGED_TAR = Path.cwd().parent / "data/merged/merged-kg.tar.gz"

# %%
tar = tarfile.open(MERGED_TAR, "r:gz")
# Extract the TSV file
for member in tar.getmembers():
    f = tar.extractfile(member)
    if '_nodes.tsv' in member.name:
        # Read the TSV file into a pandas DataFrame
        df_nodes = pd.read_csv(f, sep='\t', low_memory=False)
    elif '_edges.tsv' in member.name:
        # Read the TSV file into a pandas DataFrame
        df_edges = pd.read_csv(f, sep='\t', low_memory=False)

# Close the tar.gz file
tar.close()

# %%
df_nodes.head()
# Out:
#                  id                                        category  \
# 0       IAO:0000115                           biolink:OntologyClass
# 1       NCBITaxon:1                        biolink:OrganismalEntity
# 2      NCBITaxon:10                        biolink:OrganismalEntity
# 3     NCBITaxon:100  biolink:OrganismTaxon|biolink:OrganismalEntity
# 4  NCBITaxon:100000                        biolink:OrganismalEntity
#
#                       name description                                  xref  \
# 0               definition         NaN                                   NaN
# 1                     root         NaN   GC_ID:1|PMID:30365038|PMID:32761142
# 2               Cellvibrio         NaN  GC_ID:11|PMID:12710603|PMID:24105943
# 3   Ancylobacter aquaticus         NaN                              GC_ID:11
# 4  Herbaspirillum sp. BA12         NaN                              GC_ID:11
#
#   provided_by                  synonym  \
# 0       Graph                      NaN
# 1       Graph                      all
# 2       Graph                      NaN
# 3       Graph    Microcyclus aquaticus
# 4       Graph  Herbispirillum sp. BA12
#
#                                                  iri  object  predicate  \
# 0  http://purl.obolibrary.org/obo/IAO_0000115|htt...     NaN        NaN
# 1         http://purl.obolibrary.org/obo/NCBITaxon_1     NaN        NaN
# 2        http://purl.obolibrary.org/obo/NCBITaxon_10     NaN        NaN
# 3       http://purl.obolibrary.org/obo/NCBITaxon_100     NaN        NaN
# 4    http://purl.obolibrary.org/obo/NCBITaxon_100000     NaN        NaN
#
#    relation  same_as  subject subsets
# 0       NaN      NaN      NaN     NaN
# 1       NaN      NaN      NaN     NaN
# 2       NaN      NaN      NaN     NaN
# 3       NaN      NaN      NaN     NaN
# 4       NaN      NaN      NaN     NaN

# %%
df_edges.head()
# Out:
#                                               id        subject  \
# 0  urn:uuid:c672b249-cb5c-4ed6-b6f6-944bbf690d10   NCBITaxon:10
# 1  urn:uuid:a9b6d704-f957-483d-a02f-5b0dda8b2aca  NCBITaxon:100
# 2  urn:uuid:dcf90aaa-34fb-494c-afb8-dd30286457be  NCBITaxon:100
# 3  urn:uuid:94f4ef9b-867e-4300-a720-2d5d7ca54230  NCBITaxon:100
# 4  urn:uuid:e69ce7ed-ac8e-4d34-9657-d511661af66d  NCBITaxon:100
#
#              predicate                                      object  \
# 0  biolink:subclass_of                           NCBITaxon:1706371
# 1  biolink:subclass_of                                NCBITaxon:99
# 2    biolink:occurs_in                          mediadive.medium:7
# 3   biolink:capable_of     traits.pathways:hydrogen_oxidation_dark
# 4   biolink:capable_of  traits.pathways:aerobic_chemo_heterotrophy
#
#           relation  provided_by knowledge_source
# 0  rdfs:subClassOf          NaN            Graph
# 1  rdfs:subClassOf          NaN            Graph
# 2      BAO:0002924          NaN            Graph
# 3       RO:0002215          NaN            Graph
# 4       RO:0002215          NaN            Graph

# %%
all_ingredients_obj = df_edges.loc[df_edges['object'].str.contains("ingredient")]

# %%
all_ingredients_obj['subject'].str.split(":").str[0].unique()
# Out:
# array(['mediadive.solution'], dtype=object)

# %%
df_edges['subject'].str.split(":").str[0].unique()
# Out:
# array(['NCBITaxon', 'OBO', 'CHEBI', 'mediadive.medium',
#        'mediadive.solution'], dtype=object)

# %%
df_edges['object'].str.split(":").str[0].unique()
# Out:
# array(['NCBITaxon', 'mediadive.medium', 'traits.pathways', 'ENVO',
#        'ECOCORE', 'traits.cell_shape_enum', 'UBERON',
#        'traits.data_source', 'CHEBI', 'GO', ' ENVO',
#        'traits.carbon_substrates', 'PO', 'FOODON', 'OBO',
#        'mediadive.solution', 'CAS-RN', 'mediadive.ingredient', 'PubChem',
#        'KEGG'], dtype=object)

# %%
df_edges.loc[df_edges['subject']=="mediadive.medium:1a"]
# Out:
#                                                     id              subject  \
# 1238825  urn:uuid:fca2ce48-83ed-4b77-b8ab-0c777200f11b  mediadive.medium:1a
#
#                 predicate                object     relation  provided_by  \
# 1238825  biolink:has_part  mediadive.solution:3  BFO:0000051          NaN
#
#         knowledge_source
# 1238825            Graph

# %%
df_edges.loc[df_edges['subject']=="mediadive.solution:3"]
# Out:
#                                                     id               subject  \
# 1242381  urn:uuid:afcaaa96-a631-4411-83a0-a1f06cd47ff4  mediadive.solution:3
# 1242382  urn:uuid:bd0dfa4a-7f76-4352-a930-22f24af1ea95  mediadive.solution:3
# 1242383  urn:uuid:eee7ea6f-b0f2-487f-b20c-2c2f2da430e1  mediadive.solution:3
# 1242384  urn:uuid:b244b12c-da42-4704-a2dd-9dc6f2fe6ea2  mediadive.solution:3
#
#                 predicate                  object     relation  provided_by  \
# 1242381  biolink:has_part       CAS-RN:73049-73-7  BFO:0000051          NaN
# 1242382  biolink:has_part  mediadive.ingredient:2  BFO:0000051          NaN
# 1242383  biolink:has_part              CHEBI:2509  BFO:0000051          NaN
# 1242384  biolink:has_part             CHEBI:15377  BFO:0000051          NaN
#
#         knowledge_source
# 1242381            Graph
# 1242382            Graph
# 1242383            Graph
# 1242384            Graph

# %%
subj_pattern = ['mediadive.medium:', 'mediadive.solution:']
obj_pattern = ['mediadive.solution:', 'mediadive.ingredient:']

condition_1 = df_edges['subject'].str.contains('|'.join(subj_pattern))
condition_2 = df_edges['object'].str.contains('|'.join(obj_pattern))

df_mediadive = df_edges[condition_1 & condition_2]

# mapping = df_edges.set_index('object')['subject'].to_dict()

# mapping
df_mediadive
# Out:
#                                                     id  \
# 1238696  urn:uuid:81d626e0-5e93-4267-b1a9-64e77387e4c3
# 1238697  urn:uuid:4252ea08-bf3a-4d57-8d06-ed86071c60f2
# 1238698  urn:uuid:d08f7854-1b63-426e-b884-31155aec768b
# 1238699  urn:uuid:81a2bebc-6f31-4d5f-8f24-e0d706971097
# 1238700  urn:uuid:da80845a-036c-4986-859e-98c1b52a986b
# ...                                                ...
# 1323513  urn:uuid:fd6bd96c-525d-4c7b-83a8-4b82f89e0d69
# 1323514  urn:uuid:a9e9623d-ed2a-4978-bd72-042a99924508
# 1323515  urn:uuid:45289744-8054-41f1-b325-3f9ce05526ce
# 1323524  urn:uuid:8502f0df-056c-4d87-99ce-e0ce1dbc802c
# 1323539  urn:uuid:b37cedbf-981d-4d44-a7ff-ba6070953141
#
#                          subject         predicate                   object  \
# 1238696    mediadive.medium:1669  biolink:has_part  mediadive.solution:3464
# 1238697      mediadive.medium:92  biolink:has_part   mediadive.solution:161
# 1238698    mediadive.medium:1609  biolink:has_part  mediadive.solution:3351
# 1238699     mediadive.medium:830  biolink:has_part  mediadive.solution:1685
# 1238700      mediadive.medium:65  biolink:has_part   mediadive.solution:106
# ...                          ...               ...                      ...
# 1323513    mediadive.medium:C109  biolink:has_part  mediadive.solution:6100
# 1323514    mediadive.medium:C110  biolink:has_part  mediadive.solution:6101
# 1323515    mediadive.medium:C110  biolink:has_part  mediadive.solution:6248
# 1323524  mediadive.solution:6101  biolink:has_part  mediadive.solution:6248
# 1323539  mediadive.solution:6248  biolink:has_part  mediadive.solution:6248
#
#             relation  provided_by knowledge_source
# 1238696  BFO:0000051          NaN            Graph
# 1238697  BFO:0000051          NaN            Graph
# 1238698  BFO:0000051          NaN            Graph
# 1238699  BFO:0000051          NaN            Graph
# 1238700  BFO:0000051          NaN            Graph
# ...              ...          ...              ...
# 1323513  BFO:0000051          NaN            Graph
# 1323514  BFO:0000051          NaN            Graph
# 1323515  BFO:0000051          NaN            Graph
# 1323524  BFO:0000051          NaN            Graph
# 1323539  BFO:0000051          NaN            Graph
#
# [27181 rows x 7 columns]

# %%
medium_subject_condition = df_mediadive["subject"].str.startswith("mediadive.medium:")
solution_object_condition = df_mediadive["object"].str.startswith("mediadive.solution:")

medium_solution_df = df_mediadive[medium_subject_condition & solution_object_condition]
medium_solution_df
# Out:
#                                                     id                subject  \
# 1238696  urn:uuid:81d626e0-5e93-4267-b1a9-64e77387e4c3  mediadive.medium:1669
# 1238697  urn:uuid:4252ea08-bf3a-4d57-8d06-ed86071c60f2    mediadive.medium:92
# 1238698  urn:uuid:d08f7854-1b63-426e-b884-31155aec768b  mediadive.medium:1609
# 1238699  urn:uuid:81a2bebc-6f31-4d5f-8f24-e0d706971097   mediadive.medium:830
# 1238700  urn:uuid:da80845a-036c-4986-859e-98c1b52a986b    mediadive.medium:65
# ...                                                ...                    ...
# 1323473  urn:uuid:5effd6d3-f30f-4262-ba82-b50f535780d1  mediadive.medium:C108
# 1323474  urn:uuid:5e85d94d-3d61-4afd-bd5e-1ea1ce46b941  mediadive.medium:C108
# 1323513  urn:uuid:fd6bd96c-525d-4c7b-83a8-4b82f89e0d69  mediadive.medium:C109
# 1323514  urn:uuid:a9e9623d-ed2a-4978-bd72-042a99924508  mediadive.medium:C110
# 1323515  urn:uuid:45289744-8054-41f1-b325-3f9ce05526ce  mediadive.medium:C110
#
#                 predicate                   object     relation  provided_by  \
# 1238696  biolink:has_part  mediadive.solution:3464  BFO:0000051          NaN
# 1238697  biolink:has_part   mediadive.solution:161  BFO:0000051          NaN
# 1238698  biolink:has_part  mediadive.solution:3351  BFO:0000051          NaN
# 1238699  biolink:has_part  mediadive.solution:1685  BFO:0000051          NaN
# 1238700  biolink:has_part   mediadive.solution:106  BFO:0000051          NaN
# ...                   ...                      ...          ...          ...
# 1323473  biolink:has_part  mediadive.solution:6160  BFO:0000051          NaN
# 1323474  biolink:has_part  mediadive.solution:6246  BFO:0000051          NaN
# 1323513  biolink:has_part  mediadive.solution:6100  BFO:0000051          NaN
# 1323514  biolink:has_part  mediadive.solution:6101  BFO:0000051          NaN
# 1323515  biolink:has_part  mediadive.solution:6248  BFO:0000051          NaN
#
#         knowledge_source
# 1238696            Graph
# 1238697            Graph
# 1238698            Graph
# 1238699            Graph
# 1238700            Graph
# ...                  ...
# 1323473            Graph
# 1323474            Graph
# 1323513            Graph
# 1323514            Graph
# 1323515            Graph
#
# [8525 rows x 7 columns]

# %%
solution_subject_condition = df_mediadive["subject"].str.startswith("mediadive.solution:")
ingredient_object_condition = df_mediadive["object"].str.startswith("mediadive.ingredient:")

solution_ingredient_df = df_mediadive[solution_subject_condition & ingredient_object_condition]
solution_ingredient_df
# Out:
#                                                     id  \
# 1242308  urn:uuid:b9ade932-9026-4c0d-8251-82e7c33b6b34
# 1242313  urn:uuid:dc6c9431-1b9a-4c78-8981-a398bada59e8
# 1242314  urn:uuid:a297fada-720c-4e63-93fb-c67329cf82a0
# 1242315  urn:uuid:fe6fc976-9d7a-4d78-875f-5f45ef52e2bb
# 1242317  urn:uuid:187c2890-04fe-4b67-9e2d-a91f39545620
# ...                                                ...
# 1323369  urn:uuid:7d40ab2c-68b8-4ae7-8618-33b91a83b004
# 1323383  urn:uuid:33c7caaa-441a-4841-80d5-3eba7c213962
# 1323479  urn:uuid:6bea3fc9-0e8e-4bf5-b4a4-23efdaaa6b49
# 1323485  urn:uuid:6e9c3418-a455-4052-80bd-9486d18d40b6
# 1323494  urn:uuid:465cc19e-e38c-49b6-a8f8-d38ede54ff4f
#
#                          subject         predicate                     object  \
# 1242308     mediadive.solution:1  biolink:has_part     mediadive.ingredient:2
# 1242313     mediadive.solution:1  biolink:has_part  mediadive.ingredient:2111
# 1242314     mediadive.solution:1  biolink:has_part   mediadive.ingredient:724
# 1242315     mediadive.solution:1  biolink:has_part  mediadive.ingredient:2110
# 1242317     mediadive.solution:1  biolink:has_part  mediadive.ingredient:2112
# ...                          ...               ...                        ...
# 1323369  mediadive.solution:6241  biolink:has_part   mediadive.ingredient:286
# 1323383  mediadive.solution:6242  biolink:has_part   mediadive.ingredient:286
# 1323479  mediadive.solution:6247  biolink:has_part   mediadive.ingredient:286
# 1323485  mediadive.solution:6099  biolink:has_part   mediadive.ingredient:286
# 1323494  mediadive.solution:6246  biolink:has_part   mediadive.ingredient:286
#
#             relation  provided_by knowledge_source
# 1242308  BFO:0000051          NaN            Graph
# 1242313  BFO:0000051          NaN            Graph
# 1242314  BFO:0000051          NaN            Graph
# 1242315  BFO:0000051          NaN            Graph
# 1242317  BFO:0000051          NaN            Graph
# ...              ...          ...              ...
# 1323369  BFO:0000051          NaN            Graph
# 1323383  BFO:0000051          NaN            Graph
# 1323479  BFO:0000051          NaN            Graph
# 1323485  BFO:0000051          NaN            Graph
# 1323494  BFO:0000051          NaN            Graph
#
# [1962 rows x 7 columns]
